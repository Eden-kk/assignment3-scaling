# %% [markdown]
# # Local Scaling Workflow
#
# This notebook is a thin starter for running the scaling-law experiment locally on Colab, CUDA, MPS, or CPU while logging to Weights & Biases.
#
# The surrounding Python package already contains the scaffolding. Your main implementation work lives in `cs336_scaling/local_scaling/hooks.py`.

# %%
# Colab install cell
# !pip install -U torch wandb matplotlib scipy
# !pip install -e .

# %%
from cs336_scaling.local_scaling import ExperimentConfig, run_local_experiment
from cs336_scaling.local_scaling.device import select_device

config = ExperimentConfig.from_json('../configs/local_scaling_example.json')
print(select_device(config.training.device_preference))
config

# %% [markdown]
# ## Suggested workflow
#
# 1. Fill in the `TODO` sections in `cs336_scaling/local_scaling/hooks.py`.
# 2. Edit the JSON config for a pilot run.
# 3. Set `config.wandb.enabled = True` once W&B is configured.
# 4. Run one job locally to verify the full pipeline.
# 5. Move to `scripts/run_wandb_scaling_sweep.py` for sweep execution.

# %%
# Example single-run invocation
# metrics = run_local_experiment(config)
# metrics
